# %% [markdown]
# # PROBLEMA DE NEGOCIO
# Se trata de un algoritmo capaz de analizar las caracteristicas de una propiedad -como comodidades, tamaño, ocupación del espacio en un
# período determinado- y sugerir al anfitrión un precio a cobrar por tarifas diarias que garantice ganancias en momentos de alta demanda.

# %% [markdown]
# ## 1. Entendiendo el Problema

# %%
import pandas as pd
